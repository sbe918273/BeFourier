# %% [markdown]
# ### Imports:

# %%
from numpy import sin, cos, arctan, linspace, pi, array
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from time import sleep
from IPython.display import HTML

# %% [markdown]
# ### Helper functions:

# %%
from numpy import pi, arctan

def get_arg(z):

    if z.re == 0:
        if z.im == 0:
            return 0
        elif z.im> 0:
            return 0.5*pi
        else:
            return -0.5*pi

    elif z.re > 0:
        return arctan(z.im/z.re)

    elif z.im > 0:
        return pi + arctan(z.im/z.re)

    else: 
        return -pi + arctan(z.im/z.re)

def get_mod(z):

    return (z.re**2 + z.im**2)**0.5

def center_list(t):
    med = t[int(len(t)/2)]
    return array([i-med for i in t])

# %% [markdown]
# ### Complex number class:

# %%
class Complex:

    def __init__(self, re=None, im=None, mod=None, arg=None):

        if None not in (re, im):
            self.re = re
            self.im = im
            self.mod = get_mod(self)
            self.arg = get_arg(self)
            
        else:
            self.arg = arg
            self.mod = mod
            self.re = mod * cos(arg)
            self.im = mod * sin(arg)
        
    def re(self):
        return self._re
    
    def im(self):
        return self._im

    def __str__(self):

        if self.im == 1:
            im_str = ''
        elif self.im == -1:
            im_str = '-'
        else:
            im_str = str(self.im)

        return "{}{}{}i".format(str(self.re), '+' if self.im >= 0 else '', im_str)

    def __add__(self, other):
        
        if type(other) == Complex:
            return Complex(re=self.re+other.re, im=self.im+other.im)
        
        else: 
            return Complex(re=self.re+other, im=self.im)
        
    def __radd__(self, other):
        
        return self.__add__(other)
    
    def __mul__ (self, other):
        
        if type(other) == Complex:
            return Complex(mod=self.mod*other.mod, arg=self.arg+other.arg)
        
        else:
            return Complex(mod=self.mod*other, arg=self.arg)
        
    def __rmul__ (self, other):
        
        return self.__mul__(other)
    
# Shorthand function for creating a Complex object using its modulus and argument.
# Would be written mathematically as mod*e**(i*arg).
c_exp = lambda scale, arg: scale * Complex(mod=1, arg=arg)

# %% [markdown]
# <h3><u>The wrapping function and getting its coordinates</u></h3>
#
# The `get_wrapped` function essentially wraps `g` around the pole of an Argand diagram, cycling clockwise at a rate of `nu` cycles per second. In this way, the complex outputs the `get_wrapped` function returns have a modulus equal to the function `g` at each time `t` (where `t` is also their argument). We will refer to this function as the 'wrapping' function.
#
# Similarly, the `get_wrap_coords` function gets the coordinates for a polar curve with a radius equal to the function `g` at each time `t` (where `t` is also the angle), cycling clockwise at a rate of `nu` cycles per second.

# %%
def get_wrapped(g, t, nu, start=None, end=None, num=None):
    
    start = min(t) if start is None else start
    end = max(t) if end is None else end
    
    len_t = len(t)
    num = len_t if num is None else num
    
    idxs = []
    for i in range(len_t):
        if t[i] >= start and t[i] <= end:
            idxs.append(i)
            
    idxs_len = len(idxs)
    
    step = int(idxs_len/num)
    step = 1 if step == 0 else step
            
    return [c_exp(g[i], -2*pi * nu * t[i]) for i in range(0, idxs_len, step)], start, end, num
    
def get_wrap_coords(g, t, nu, start=None, end=None, num=None):
    
    complex_set, _, _, _,  = get_wrapped(g, t, nu, start, end, num)
    return [z.re for z in complex_set], [z.im for z in complex_set]

# %% [markdown]
# <h3><u>The Fourier transform function</u></h3>
#
# The `F` function performs the Fourier transform on `g` for a wrapping frequency `nu`. However, instead of integrating from -∞ to +∞ (the entire range over which a sinusoid of that frequency could have an effect in function `g`), it performs the trapezium rule with `num` strips with the limits being the start and end of the `g` outputs.
#
# The "center" of the wrapping function between two values of `t` is the mean of all its outputs between these values. In this way, it is equal to this integral divided by the difference between the limits. Therefore, the output of `F` has the same, more pronounced, following properties of the center:
#
# As `nu` approaches the frequency of a sinusoid found in `g`, the distance this center is found from the pole increases (as the wrapping and sinusoid cycles become more coherent such that maxima and minima of the wrapping function occur at two smaller opposing ranges of `t`, shifting the center towards the values of `t` where maxima occur). This distance (directly proportional to the amplitude of the frequency) is at a maximum (as the maxima and minima only occur at fixed opposing values of `t`) when the wrapping and sinusoid frequency are equal.
#
# At this point, they are completely coherent such that the values of `t` where maxima occur at a fixed phase difference from the start of the wrapping cycles. As the wrapping cycles have an absolute phase of 0, this phase difference between the wrapping and sinusoid cycles is equal to the absolute phase of the sinusoid. As such, it is given by the argument of this center (i.e. the angle through the wrapping cycle at which these maxima occur).

# %%
def F_func(g, t, nu, start=None, end=None, num=None):
    
    y, start, end, num = get_wrapped(g, t, nu, start, end, num)
    h = (end-start)/num
    return 0.5*h*(y[0] + y[-1] + 2*sum(y[1:-1]))

# %% [markdown]
# <h3><u>Visualising the 'wrapping' function:</u></h3>

# %%
start = 0
end = 0.5*pi
num = 3000

g_func = lambda t: \
10*cos(2*pi*10*t+pi) + \
5*cos(2*pi*5*t+0.5*pi) +\
7.5*cos(2*pi*7.5*t+1.5*pi)+\
10*cos(2*pi*30*t+0.5*pi)
t = center_list(linspace(start, end, num))
g = g_func(t)

x = [t]
y = [g]
lines = []

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10,4))

# Optional reference function
#axes[0].plot(linspace(start, end, num), 9*cos(2*pi*4*x[0]))

# Center of wrapped function

center = F_func(g, t, 2, start, end, num)*(end-start)**-1
axes[1].plot(center.re, center.im, 'rx')

x_temp, y_temp = get_wrap_coords(g, t, 30)
x.append(x_temp)
y.append(y_temp)

lines = [axes[i].plot(x[i], y[i])[0] for i in range(0, len(axes))]

# %%
points = [axis.plot([], [], 'ro')[0] for axis in axes]
ref_lines = [axis.plot([], [], 'k--')[0] for axis in axes]

def animate(count):
    
    for i in range(0, len(lines)):
        
        lines[i].set_data(x[i][:count], y[i][:count])
        points[i].set_data(x[i][count], y[i][count])
        
    ref_lines[0].set_data([x[0][count], x[0][count]], [-50, 50])
    
    if x[1][count] >= 0:
        ref_lines[1].set_data(linspace(0, 50, 2), [0, 50 * (y[1][count]/x[1][count])])
    else:
        ref_lines[1].set_data(linspace(-50, 0, 2), [-50 * (y[1][count]/x[1][count]), 0])
    
anim = FuncAnimation(fig, animate, frames=num-1, interval=40)
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     250         try:
# --> 251             yield self
#     252         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1140                     # TODO: See if turning off blit is really necessary
# -> 1141                     anim._draw_next_frame(d, blit=False)
#    1142                     if progress_callback is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1176         self._draw_frame(framedata)
# -> 1177         self._post_draw(framedata, blit)
#    1178
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1201         else:
# -> 1202             self._fig.canvas.draw_idle()
#    1203
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2011             with self._idle_draw_cntx():
# -> 2012                 self.draw(*args, **kwargs)
#    2013
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/lines.py in draw(self, renderer)
#     785                 gc.set_dashes(self._dashOffset, self._dashSeq)
# --> 786                 renderer.draw_path(gc, tpath, affine.frozen())
#     787                 gc.restore()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     158             try:
# --> 159                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     160             except OverflowError as err:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-54-106053c40fa0> in <module>
#      17
#      18 anim = FuncAnimation(fig, animate, frames=num-1, interval=40)
# ---> 19 HTML(anim.to_html5_video())
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1318                                 bitrate=mpl.rcParams['animation.bitrate'],
#    1319                                 fps=1000. / self._interval)
# -> 1320                 self.save(str(path), writer=writer)
#    1321                 # Now open and base64 encode.
#    1322                 vid64 = base64.encodebytes(path.read_bytes())
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1143                         progress_callback(frame_number, total_frames)
#    1144                         frame_number += 1
# -> 1145                 writer.grab_frame(**savefig_kwargs)
#    1146
#    1147     def _step(self, *args):
#
# ~/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in finish(self)
#     352     def finish(self):
#     353         """Finish any processing for writing the movie."""
# --> 354         self.cleanup()
#     355
#     356     def grab_frame(self, **savefig_kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in cleanup(self)
#     389         if self._proc.returncode:
#     390             raise subprocess.CalledProcessError(
# --> 391                 self._proc.returncode, self._proc.args, out, err)
#     392
#     393     @classmethod
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '720x288', '-pix_fmt', 'rgba', '-r', '25.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/tmp/tmpsvizfqsr/temp.m4v']' returned non-zero exit status 255.

# %% [markdown]
# <hr>

# %%
nu = linspace(0, 40, 1000)
F = [2*F_func(g, t, i) for i in nu]

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12,8))

axes[0][0].plot(nu, [z.mod for z in F])
axes[0][1].plot(nu[250:], [z.mod for z in F[250:]])

axes[1][0].plot(nu, [z.re for z in F])
axes[1][1].plot(nu, [z.im for z in F])

# %% [markdown]
# $\int_{a}^{b} x^2 \,dx$
#
# In order to get `g` back from the output of `F`

# %%
g_hat = [F_func(F, nu, i) for i in t]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))
axes[0].plot(-1*t, [z.re for z in g_hat])
axes[1].plot(t, g)

# %% [markdown]
# <hr/>

# %%
def flatten(F, nu, start, end):
    
    F_flattened = []
    
    mean_F = sum(F)*len(F)**-1
    
    for i in range(len(nu)):
        
        if nu[i] >= start and nu[i] <= end:
            F_flattened.append(mean_F)
            
        else:
            F_flattened.append(F[i])
            
    return F_flattened

# %%
g_desire_func = lambda t: \
5*cos(2*pi*5*t+0.5*pi) + \
7.5*cos(2*pi*7.5*t+1.5*pi)
g_desire = g_desire_func(t)

F_flattened = flatten(F, nu, 20, 40)
F_flattened = flatten(F_flattened, nu, 9, 11)
g_desire_hat = [F_func(F_flattened, nu, i) for i in t]

# %%
plt.plot(nu, [z.mod for z in F_flattened])

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

axes[0].plot(-1*t, [z.re for z in g_desire_hat])
axes[1].plot(t, g_desire)
